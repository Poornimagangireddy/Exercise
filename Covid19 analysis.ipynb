# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:\\Users\\Prathiba\\Desktop\\loan.csv")
df
# Out:
# C:\Users\Prathiba\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# ...

# %%
df.head(150)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0    1077501    1296599       5000         5000       4975.00000   36 months
# 1    1077430    1314167       2500         2500       2500.00000   60 months
# 2    1077175    1313524       2400         2400       2400.00000   36 months
# 3    1076863    1277178      10000        10000      10000.00000   36 months
# 4    1075358    1311748       3000         3000       3000.00000   60 months
# ..       ...        ...        ...          ...              ...         ...
# 145  1068091    1302450      12000        12000      12000.00000   36 months
# 146  1068090    1302449      16000        16000      15975.00000   60 months
# 147  1068082    1270159      21600        21600      20498.26578   60 months
# 148  1068078    1302434       6000         6000       6000.00000   36 months
# 149  1057633    1289398       8450         8450       8425.00000   60 months
#
# ...

# %%
df.tail(50)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39667  118823     118026       2500         2500            675.0   36 months
# 39668  118533     117783       2500         2500            825.0   36 months
# 39669  118523     118519       6500         6500            225.0   36 months
# 39670  117863     117849       8000         8000           2275.0   36 months
# 39671  117794      94256       7500         7500            400.0   36 months
# 39672  117249     116607       5000         5000           1300.0   36 months
# 39673  117056     117046       5000         5000           1475.0   36 months
# 39674  116582     116502      10000        10000            975.0   36 months
# 39675  116040     116037       5000         5000            775.0   36 months
# 39676   88854      70699       5000         5000            225.0   36 months
# 39677  113194     113115       3500         3500           1725.0   36 months
# ...

# %%
df.funded_amnt
# Out:
# 0         5000
# 1         2500
# 2         2400
# 3        10000
# 4         3000
#          ...
# 39712     2500
# 39713     8500
# 39714     5000
# 39715     5000
# 39716     7500
# Name: funded_amnt, Length: 39717, dtype: int64

# %%
df.size
# Out:
# 4408587

# %%
print(df[1:10])
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
print(df.member_id[1:10])
# Out:
# 1    1314167
# 2    1313524
# 3    1277178
# 4    1311748
# 5    1311441
# 6    1304742
# 7    1288686
# 8    1306957
# 9    1306721
# Name: member_id, dtype: int64

# %%
df.shape
# Out:
# (39717, 111)

# %%
print(df.funded_amnt[1:20])
# Out:
# 1      2500
# 2      2400
# 3     10000
# 4      3000
# 5      5000
# 6      7000
# 7      3000
# 8      5600
# 9      5375
# 10     6500
# 11    12000
# 12     9000
# 13     3000
# 14    10000
# 15     1000
# 16    10000
# 17     3600
# 18     6000
# 19     9200
# Name: funded_amnt, dtype: int64

# %%
plt.boxplot(df['funded_amnt'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24b1ddca4c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24b1dde3e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24b1ddd1e88>],
#  'medians': [<matplotlib.lines.Line2D at 0x24b1ddf2fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24b1ddf2b88>],
#  'means': []}

# %%
plt.boxplot(df['loan_amnt'])
plt.xlabel('discount')
plt.ylabel('amount')
plt.xlim(10,50)
plt.ylim(100,500)
plt.show()

# %%
plt.hist(['sub_grade'])
plt.show()

# %%
plt.boxplot(df['id'])
plt.show()

# %%
plt.scatter(df['funded_amnt'],df['sub_grade'])
plt.show()

# %%
plt.scatter(df['loan_amnt'],df['grade'])
plt.show()

# %%
plt.hist(['int_rate','num_tl_op_past_12m'])
plt.show()

# %%
plt.scatter(df['installment'],df['installment'])
plt.show()

# %%
plt.subplot(1,2,1)
plt.boxplot(df['funded_amnt'])
plt.title("house loan")
plt.xlabel("time")
plt.ylabel("voltage")

plt.subplot(1,2,2)
plt.boxplot(df['funded_amnt_inv'])
plt.ylabel('poori')
plt.show()

# %%
sns.barplot(x='funded_amnt',y='term',data=df)
plt.show()

# %%
sns.barplot(x='sub_grade',y='installment',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.distplot(df['id'])
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.distplot(df['id'])
plt.show()

# %%
sns.distplot(df['num_tl_90g_dpd_24m'])
# Out:
# C:\Users\Prathiba\anaconda3\lib\site-packages\seaborn\distributions.py:200: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\Prathiba\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Prathiba\anaconda3\lib\site-packages\numpy\lib\histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
sns.distplot(df['loan_amnt'])
plt.show()

# %%
plt.subplot(2,2,1)
plt.title("univariate")
sns.jointplot('id','installment',df)
plt.show()

# %%
sns.jointplot('member_id', 'funded_amnt_inv', df, kind="hex", color="g")

# %%
x=np.linspace(1,5,10)
y=np.linspace(5,20,10)
plt.subplot(122)
#plt.figure(figsize=(10,9))
plt.xlabel("numbers")
plt.ylabel("decimals")
plt.title("subplot")
plt.plot(x,y)
plt.show()

# %%
import numpy as np
